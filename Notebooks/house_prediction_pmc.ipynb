# %% [markdown]
# # Houses Pricing Predictions : PMC

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv(r"C:/Users/straw/Desktop/AIS2/House-Prediction/Data/housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.total_bedrooms.fillna(method='pad', inplace=True)

# %%
label = LabelEncoder()

df['ocean_proximity'] = label.fit_transform(df['ocean_proximity'])
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
X = np.array(df.loc[:, ~df.columns.isin(['median_house_value'])])

# %%
y = np.array(df["median_house_value"])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size = 0.25, shuffle=True)

# %%
regressor = Sequential()
regressor.add(Dense(units=20, kernel_initializer="uniform", activation='relu', input_dim=9))
#regressor.add(Dropout(rate=0.1))
regressor.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

# %%
regressor.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_squared_error', 'mean_absolute_error'])

# %%
regressor.fit(X_scaled, y, batch_size=32, epochs=1500, validation_split=0.25)
# Out:
# Epoch 1/1500
# 484/484 [==============================] - 1s 2ms/step - loss: 199007.4688 - mean_squared_error: 51989405696.0000 - mean_absolute_error: 199007.4688 - val_loss: 230397.2500 - val_mean_squared_error: 68449681408.0000 - val_mean_absolute_error: 230397.2500
# Epoch 2/1500
# 484/484 [==============================] - 1s 1ms/step - loss: 199007.4219 - mean_squared_error: 51989323776.0000 - mean_absolute_error: 199007.4219 - val_loss: 230397.2188 - val_mean_squared_error: 68449681408.0000 - val_mean_absolute_error: 230397.2188
# Epoch 3/1500
# 484/484 [==============================] - 1s 1ms/step - loss: 199007.3125 - mean_squared_error: 51989319680.0000 - mean_absolute_error: 199007.3125 - val_loss: 230397.2188 - val_mean_squared_error: 68449681408.0000 - val_mean_absolute_error: 230397.2188
# Epoch 4/1500
# ...

# %%
y_pred = regressor.predict(X_val)

# %%
mean_absolute_error(y_val, y_pred)

# %%
r2_score(y_val, y_pred)

# %%
plt.title('Performance du modèle')
plt.plot(list(y_pred)[:50], label='Prediction')
plt.plot(list(y_val)[:50], label='True')
plt.legend()
